# %% [markdown]
# <a href='https://www.darshan.ac.in/'> <img src='https://www.darshan.ac.in/Content/media/DU_Logo.svg' width="250" height="300"/></a>
# <pre>
# <center><b><h1>PDS - 2305CS303</b></center>
# <center><b><h1>Lab - 9</b></center>
# <pre>

# %% [markdown]
# ### 01) Scrap the data of Faculty and news data from darshan university website.

# %%
# import requests
# import bs4

# req = requests.get("https://darshan.ac.in/engineering/computer/faculty")
# soup = bs4.BeautifulSoup(req.text, 'lxml')

# data = soup.select("h2")
# for d in data:
#     print(d.text.strip())

# data = soup.select("body > main > div:nth-child(5) > div > div > div.col-lg-8.col-xl-9.g-font-size-14 > div > div")
# for f in data[:-1]:
#     name = f.select("h2")
#     a = f.select("span")
#     print(name[0].text.strip(), "-->", a[1].text.strip())

import requests
import bs4

req = requests.get("https://www.darshan.ac.in/news-post/list")
soup = bs4.BeautifulSoup(req.text, 'lxml')

data = soup.select(".event-post")  # Assuming each news item is in a div with class 'event-post'
for item in data:
    title = item.select_one(".event-title").text.strip()  # Assuming the title is in a class 'event-title'
    date = item.select_one(".event-date").text.strip()    # Assuming the date is in a class 'event-date'
    print(f"Title: {title} | Date: {date}")

# %% [markdown]
# ### 01) Write a Python program to perform web scrapping  from rajkot information technology association Website
